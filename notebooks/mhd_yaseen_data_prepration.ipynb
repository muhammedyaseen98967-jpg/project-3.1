# %%
import sqlite3
import pandas as pd
con=sqlite3.connect('C:\\Users\\yasee\\OneDrive\\Desktop\\Sem 3 projects\\project 3.1\\data\\raw\\ipl.db')

def q(sql):
    return pd.read_sql(sql,con)

# %%
def run_sql_file(path):
    with open(path,'r') as f:
        script=f.read()
        con.executescript(script)
        con.commit()
        print('ran',path)

# %%
run_sql_file("C:\\Users\\yasee\\OneDrive\\Desktop\\Sem 3 projects\\project 3.1\\sql\\test.sql")
# Out:
# ran C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\test.sql

# %%
run_sql_file("C:\\Users\\yasee\\OneDrive\\Desktop\\Sem 3 projects\\project 3.1\\sql\\practice\\01_nulls_and_blanks.sql")
# Out:
# ran C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\practice\01_nulls_and_blanks.sql

# %%
q("""SELECT COUNT(*) AS blank_before
FROM players
WHERE TRIM(field_pos) = '';""")
# Out:
#    blank_before
# 0           612

# %%
q("""SELECT COUNT(*) AS null_after
  FROM v_players_clean
  WHERE field_pos_clean IS NULL;""")
# Out:
#    null_after
# 0         700

# %%
run_sql_file(r"C:\\Users\\yasee\\OneDrive\\Desktop\\Sem 3 projects\\project 3.1\\sql\\practice\\02_merge_categories.sql")
# Out:
# ran C:\\Users\\yasee\\OneDrive\\Desktop\\Sem 3 projects\\project 3.1\\sql\\practice\\02_merge_categories.sql

# %%
q("""SELECT DISTINCT team_name 
FROM teams
ORDER BY team_name;""")
# Out:
#                       team_name
# 0           Chennai Super Kings
# 1               Deccan Chargers
# 2                Delhi Capitals
# 3                 Gujarat Lions
# 4                Gujarat Titans
# 5          Kochi Tuskers Kerala
# 6         Kolkata Knight Riders
# 7          Lucknow Super Giants
# 8                Mumbai Indians
# 9                 Pune Warriors
# 10                 Punjab Kings
# 11             Rajasthan Royals
# 12       Rising Pune Supergiant
# 13      Rising Pune Supergiants
# 14  Royal Challengers Bangalore
# 15          Sunrisers Hyderabad

# %%
run_sql_file(r'C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\practice\03_venue_names.sql')
# Out:
# ran C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\practice\03_venue_names.sql

# %%
q("""SELECT venue,count(*) as matches
FROM matches
WHERE venue IN('Wankhede Stadium','Wankhede Stadium, Mumbai')
GROUP BY venue;""")
# Out:
#                       venue  matches
# 0          Wankhede Stadium       73
# 1  Wankhede Stadium, Mumbai       57

# %%
q("""SELECT venue, COUNT(*) AS matches
FROM matches
GROUP BY venue
ORDER BY matches DESC LIMIT 5;""")
# Out:
#                       venue  matches
# 0              Eden Gardens       77
# 1          Wankhede Stadium       73
# 2     M Chinnaswamy Stadium       65
# 3          Feroz Shah Kotla       60
# 4  Wankhede Stadium, Mumbai       57

# %%
q("""SELECT venue_clean,COUNT(*) AS matches 
FROM v_matches_venue
GROUP BY venue_clean
ORDER BY matches DESC LIMIT 5;""")
# Out:
#                           venue_clean  matches
# 0                    Wankhede Stadium      130
# 1                        Eden Gardens      104
# 2              MA Chidambaram Stadium       95
# 3               M Chinnaswamy Stadium       89
# 4  Rajiv Gandhi International Stadium       87

# %%
q("""SELECT COUNT(*) AS rows, COUNT (DISTINCT venue) AS names
FROM venues;""")
# Out:
#    rows  names
# 0    63     59

# %%
q("""SELECT count(*),venue,city
FROM venues
GROUP BY venue
ORDER BY COUNT(*) DESC
LIMIT 10;""")
# Out:
#    count(*)                                              venue       city
# 0         2                            Sharjah Cricket Stadium        NaN
# 1         2  Maharaja Yadavindra Singh International Cricke...     Mohali
# 2         2                Dubai International Cricket Stadium        NaN
# 3         2                 Dr DY Patil Sports Academy, Mumbai     Mumbai
# 4         1                   Zayed Cricket Stadium, Abu Dhabi  Abu Dhabi
# 5         1                           Wankhede Stadium, Mumbai     Mumbai
# 6         1                                   Wankhede Stadium     Mumbai
# 7         1       Vidarbha Cricket Association Stadium, Jamtha     Nagpur
# 8         1                                    SuperSport Park  Centurion
# 9         1                         Subrata Roy Sahara Stadium       Pune

# %%
run_sql_file(r'C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\practice\04_dedope_venues.sql')
# Out:
# ran C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\practice\04_dedope_venues.sql

# %%
q("""SELECT COUNT(*),venue,city
FROM v_venues_clean
GROUP BY venue
ORDER BY COUNT(*) DESC
LIMIT 10;""")
# Out:
#    COUNT(*)                                             venue            city
# 0         1                  Zayed Cricket Stadium, Abu Dhabi       Abu Dhabi
# 1         1                          Wankhede Stadium, Mumbai          Mumbai
# 2         1                                  Wankhede Stadium          Mumbai
# 3         1      Vidarbha Cricket Association Stadium, Jamtha          Nagpur
# 4         1                                   SuperSport Park       Centurion
# 5         1                        Subrata Roy Sahara Stadium            Pune
# 6         1                                  St George's Park  Port Elizabeth
# 7         1                              Sheikh Zayed Stadium       Abu Dhabi
# 8         1                           Sharjah Cricket Stadium         Sharjah
# 9         1  Shaheed Veer Narayan Singh International Stadium          Raipur

# %%
run_sql_file(r"C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\practice\05_city_fallback.sql")
# Out:
# ran C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\practice\05_city_fallback.sql

# %%
q("""SELECT  city_clean from v_city_clean where city_clean is null;""")
# Out:
# Empty DataFrame
# Columns: [city_clean]
# Index: []

# %%
q("""SELECT venue,
count(*) AS no_city 
FROm matches
WHERE city IS NULL
GROUP BY venue""")
# Out:
#                                  venue  no_city
# 0  Dubai International Cricket Stadium       33
# 1              Sharjah Cricket Stadium       18

# %%
run_sql_file(r'C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\practice\06_season_year.sql')
# Out:
# ran C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\practice\06_season_year.sql

# %%
q("""SELECT season,
       COUNT(*) AS matches 
FROM matches 
WHERE season = '2020/21'
GROUP BY season;""")
# Out:
#     season  matches
# 0  2020/21       60

# %%
q("""SELECT DISTINCT season,season_year FROM v_season WHERE season ='2020/21';""")
# Out:
#     season  season_year
# 0  2020/21         2020

# %%
run_sql_file(r'C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\practice\07_win_definition.sql')
# Out:
# ran C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\practice\07_win_definition.sql

# %%
q("""SELECT * FROM matches_clean;""")
# Out:
#       match_id                                        venue_clean  \
# 0       335982                              M Chinnaswamy Stadium
# 1      1082591                 Rajiv Gandhi International Stadium
# 2      1082592            Maharashtra Cricket Association Stadium
# 3      1082593             Saurashtra Cricket Association Stadium
# 4      1082594                             Holkar Cricket Stadium
# ...        ...                                                ...
# 1207   1529282                               Arun Jaitley Stadium
# 1208   1529283  Maharaja Yadavindra Singh International Cricke...
# 1209   1529284                                   Wankhede Stadium
# 1210   1529285                              Narendra Modi Stadium
# 1211   1529286                             Sawai Mansingh Stadium
#
#           city_clean  season_year result                 match_winner  \
# 0          Bangalore         2008    win        Kolkata Knight Riders
# ...

# %%
run_sql_file(r'c:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\practice\08_matches_clean.sql')
# Out:
# ran c:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\practice\08_matches_clean.sql

# %%
import ast
import pandas as pd
d = pd.read_sql('SELECT * FROM deliveries WHERE fielders_involved IS NOT NULL ', con )
d['fielders']=d['fielders_involved'].apply(ast.literal_eval)

d=d.explode('fielders')
d['fielders'].value_counts().head(5)
# Out:
# fielders
# MS Dhoni          258
# KD Karthik        228
# RV Uthappa        169
# AB de Villiers    148
# V Kohli           142
# Name: count, dtype: int64

# %%
q("""SELECT result,COUNt(*) AS n
FROM matches 
GROUP BY result;""")
# Out:
#       result     n
# 0  no result     9
# 1        tie    16
# 2        win  1187
