# %%
import sqlite3
import pandas as pd

con=sqlite3.connect('C:\\Users\\yasee\\OneDrive\\Desktop\\Sem 3 projects\\project 3.1\\data\\raw\\ipl.db')
def q(sql):
    return pd.read_sql_query(sql,con)

# %%
q("""select * from venues ;""")
# Out:
#     venue_id                                              venue  \
# 0          1                              M Chinnaswamy Stadium
# 1          2          Rajiv Gandhi International Stadium, Uppal
# 2          3            Maharashtra Cricket Association Stadium
# 3          4             Saurashtra Cricket Association Stadium
# 4          5                             Holkar Cricket Stadium
# ..       ...                                                ...
# 58        59                         Subrata Roy Sahara Stadium
# 59        60   Shaheed Veer Narayan Singh International Stadium
# 60        61                 JSCA International Stadium Complex
# 61        62  Maharaja Yadavindra Singh International Cricke...
# 62        63  Maharaja Yadavindra Singh International Cricke...
#
#               city
# 0        Bangalore
# 1        Hyderabad
# 2             Pune
# 3           Rajkot
# 4           Indore
# ..             ...
# 58            Pune
# 59          Raipur
# ...

# %%
q("""select * from matches ;""")
# Out:
#       match_id  season_id  balls_per_over            city  match_date  \
# 0       335982       2008               6       Bangalore  2008-04-18
# 1      1082591       2017               6       Hyderabad  2017-04-05
# 2      1082592       2017               6            Pune  2017-04-06
# 3      1082593       2017               6          Rajkot  2017-04-07
# 4      1082594       2017               6          Indore  2017-04-08
# ...        ...        ...             ...             ...         ...
# 1207   1529282       2026               6           Delhi  2026-04-27
# 1208   1529283       2026               6  New Chandigarh  2026-04-28
# 1209   1529284       2026               6          Mumbai  2026-04-29
# 1210   1529285       2026               6       Ahmedabad  2026-04-30
# 1211   1529286       2026               6          Jaipur  2026-05-01
#
#                  event_name  match_number gender match_type format  ...  \
# ...

# %%
q("""select * from deliveries ;""")
# Out:
#         season_id  match_id           batter          bowler      non_striker  \
# 0            2008    335982       SC Ganguly         P Kumar      BB McCullum
# 1            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 2            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 3            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 4            2008    335982      BB McCullum         P Kumar       SC Ganguly
# ...           ...       ...              ...             ...              ...
# 288221       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288222       2026   1529286  Ashutosh Sharma       JC Archer         T Stubbs
# 288223       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288224       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
# 288225       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
#
# ...

# %%
q("""select * from teams  ;""")
# Out:
#     team_id                    team_name
# 0         1  Royal Challengers Bangalore
# 1         2          Sunrisers Hyderabad
# 2         3               Mumbai Indians
# 3         4       Rising Pune Supergiant
# 4         5                Gujarat Lions
# 5         6        Kolkata Knight Riders
# 6       129          Chennai Super Kings
# 7       134             Rajasthan Royals
# 8       252               Delhi Capitals
# 9       494                 Punjab Kings
# 10      614         Lucknow Super Giants
# 11      615               Gujarat Titans
# 12     1068              Deccan Chargers
# 13     1414         Kochi Tuskers Kerala
# 14     1419                Pune Warriors
# 15     3604      Rising Pune Supergiants

# %%
q("""select * from players ;""")
# Out:
#      player_id    player_name       bat_style  \
# 0          963     MN Samuels  Right hand Bat
# 1           53      SB Jakati   Left hand Bat
# 2           12      DA Warner   Left hand Bat
# 3          268    RA Tripathi  Right hand Bat
# 4          186       S Nadeem  Right hand Bat
# ..         ...            ...             ...
# 794       8475  Suyash Sharma  Right hand Bat
# 795      45004   D Madushanka  Right hand Bat
# 796      42566  V Suryavanshi   Left hand Bat
# 797         26         N Rana   Left hand Bat
# 798      45986      SU Parakh   Left hand Bat
#
#                                          bowl_style field_pos  \
# 0                                Right arm Offbreak
# 1                            Slow Left arm Orthodox
# 2                                          Legbreak
# 3                                  Right arm Medium
# 4                            Slow Left arm Orthodox
# ..                                              ...       ...
# ...

# %%
q("""select * from matches limit 15;""")
# Out:
#     match_id  season_id  balls_per_over       city  match_date  \
# 0     335982       2008               6  Bangalore  2008-04-18
# 1    1082591       2017               6  Hyderabad  2017-04-05
# 2    1082592       2017               6       Pune  2017-04-06
# 3    1082593       2017               6     Rajkot  2017-04-07
# 4    1082594       2017               6     Indore  2017-04-08
# 5    1082595       2017               6  Bengaluru  2017-04-08
# 6    1082596       2017               6  Hyderabad  2017-04-09
# 7    1082597       2017               6     Mumbai  2017-04-09
# 8    1082598       2017               6     Indore  2017-04-10
# 9    1082599       2017               6       Pune  2017-04-11
# 10   1082600       2017               6     Mumbai  2017-04-12
# 11   1082601       2017               6    Kolkata  2017-04-13
# 12   1082602       2017               6  Bangalore  2017-04-14
# 13   1082603       2017               6     Rajkot  2017-04-14
# ...

# %%
q("""select match_id,city,venue from matches limit 15;""")
# Out:
#     match_id       city                                      venue
# 0     335982  Bangalore                      M Chinnaswamy Stadium
# 1    1082591  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 2    1082592       Pune    Maharashtra Cricket Association Stadium
# 3    1082593     Rajkot     Saurashtra Cricket Association Stadium
# 4    1082594     Indore                     Holkar Cricket Stadium
# 5    1082595  Bengaluru                      M.Chinnaswamy Stadium
# 6    1082596  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 7    1082597     Mumbai                           Wankhede Stadium
# 8    1082598     Indore                     Holkar Cricket Stadium
# 9    1082599       Pune    Maharashtra Cricket Association Stadium
# 10   1082600     Mumbai                           Wankhede Stadium
# 11   1082601    Kolkata                               Eden Gardens
# 12   1082602  Bangalore                      M Chinnaswamy Stadium
# ...

# %%
q("""select batter ,bowler from deliveries limit 5;""")
# Out:
#         batter   bowler
# 0   SC Ganguly  P Kumar
# 1  BB McCullum  P Kumar
# 2  BB McCullum  P Kumar
# 3  BB McCullum  P Kumar
# 4  BB McCullum  P Kumar

# %%
q("""SELECT DISTINCT batsman_type from deliveries;""")
# Out:
#      batsman_type
# 0   Left hand Bat
# 1  Right hand Bat
# 2             NaN

# %%
q("""select * from deliveries ;""")
# Out:
#         season_id  match_id           batter          bowler      non_striker  \
# 0            2008    335982       SC Ganguly         P Kumar      BB McCullum
# 1            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 2            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 3            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 4            2008    335982      BB McCullum         P Kumar       SC Ganguly
# ...           ...       ...              ...             ...              ...
# 288221       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288222       2026   1529286  Ashutosh Sharma       JC Archer         T Stubbs
# 288223       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288224       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
# 288225       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
#
# ...

# %%
q("""SELECT DISTINCT bowler_type from deliveries;""")
# Out:
#                                        bowler_type
# 0                                 Right arm Medium
# 1                             Left arm Fast medium
# 2                            Right arm Fast medium
# 3                           Slow Left arm Orthodox
# 4                                  Legbreak Googly
# 5                            Right arm Medium fast
# 6                                   Right arm Fast
# 7                                    Left arm Fast
# 8                                  Left arm Medium
# 9                             Left arm Medium fast
# 10                              Right arm Offbreak
# 11                                        Legbreak
# 12                             Left arm Wrist spin
# 13  Right arm Medium, Right arm Offbreak, Legbreak
# 14                    Right arm Offbreak, Legbreak
# 15             Right arm Offbreak, Legbreak Googly
# 16            Right arm Medium, Right arm Offbreak
# ...

# %%
q("""SELECT DISTINCT season FROM matches;""")
# Out:
#      season
# 0      2008
# 1      2009
# 2      2010
# 3      2011
# 4      2012
# 5      2013
# 6      2014
# 7      2015
# 8      2016
# 9      2017
# 10     2018
# 11     2019
# 12  2020/21
# 13     2021
# 14     2022
# 15     2023
# 16     2024
# 17     2025
# 18     2026

# %%
q("""SELECT DISTINCT player_full_name FROM players""")
# Out:
#              player_full_name
# 0    Marlon Nathaniel Samuels
# 1        Shadab Bashir Jakati
# 2         David Andrew Warner
# 3         Rahul Ajay Tripathi
# 4              Shahbaz Nadeem
# ..                        ...
# 794             Suyash Sharma
# 795         K Dasun Madusanka
# 796       Vaibhav Suryavanshi
# 797               Nitish Rana
# 798        Sahil Ulhas Parakh
#
# [799 rows x 1 columns]

# %%
q("""SELECT match_id,season_id,city,match_winner from matches where match_winner="Chennai Super Kings";""")
# Out:
#      match_id  season_id       city         match_winner
# 0     1136561       2018     Mumbai  Chennai Super Kings
# 1     1136565       2018    Chennai  Chennai Super Kings
# 2     1136577       2018       Pune  Chennai Super Kings
# 3     1136580       2018  Hyderabad  Chennai Super Kings
# 4     1136584       2018  Bengaluru  Chennai Super Kings
# ..        ...        ...        ...                  ...
# 141   1473494       2025    Kolkata  Chennai Super Kings
# 142   1473504       2025  Ahmedabad  Chennai Super Kings
# 143   1527691       2026    Chennai  Chennai Super Kings
# 144   1529265       2026    Chennai  Chennai Super Kings
# 145   1529276       2026     Mumbai  Chennai Super Kings
#
# [146 rows x 4 columns]

# %%
q("""SELECT match_id,city,venue FROM matches WHERE season>=2015;""")
# Out:
#      match_id            city  \
# 0      829705         Kolkata
# 1      829707         Chennai
# 2      829709            Pune
# 3      829711         Chennai
# 4      829713         Kolkata
# ..        ...             ...
# 749   1529282           Delhi
# 750   1529283  New Chandigarh
# 751   1529284          Mumbai
# 752   1529285       Ahmedabad
# 753   1529286          Jaipur
#
#                                                  venue
# 0                                         Eden Gardens
# 1                      MA Chidambaram Stadium, Chepauk
# 2              Maharashtra Cricket Association Stadium
# 3                      MA Chidambaram Stadium, Chepauk
# 4                                         Eden Gardens
# ..                                                 ...
# 749                        Arun Jaitley Stadium, Delhi
# 750  Maharaja Yadavindra Singh International Cricke...
# 751                           Wankhede Stadium, Mumbai
# ...

# %%
q("""SELECT match_id,city,venue FROM matches WHERE season<=2015;""")
# Out:
#      match_id        city                                       venue
# 0      335982   Bangalore                       M Chinnaswamy Stadium
# 1      335983  Chandigarh  Punjab Cricket Association Stadium, Mohali
# 2      335984       Delhi                            Feroz Shah Kotla
# 3      335985      Mumbai                            Wankhede Stadium
# 4      335986     Kolkata                                Eden Gardens
# ..        ...         ...                                         ...
# 512    829815   Hyderabad   Rajiv Gandhi International Stadium, Uppal
# 513    829817      Mumbai                            Wankhede Stadium
# 514    829819        Pune     Maharashtra Cricket Association Stadium
# 515    829821      Ranchi          JSCA International Stadium Complex
# 516    829823     Kolkata                                Eden Gardens
#
# [517 rows x 3 columns]

# %%
q("""SELECT match_id,city,venue FROM matches WHERE season>=2015 and  city="Bangalore";""")
# Out:
#     match_id       city                  venue
# 0     829719  Bangalore  M Chinnaswamy Stadium
# 1     829737  Bangalore  M Chinnaswamy Stadium
# 2     829745  Bangalore  M Chinnaswamy Stadium
# 3     829763  Bangalore  M Chinnaswamy Stadium
# 4     829771  Bangalore  M Chinnaswamy Stadium
# 5     829785  Bangalore  M Chinnaswamy Stadium
# 6     829813  Bangalore  M Chinnaswamy Stadium
# 7     980907  Bangalore  M Chinnaswamy Stadium
# 8     980921  Bangalore  M Chinnaswamy Stadium
# 9     980959  Bangalore  M Chinnaswamy Stadium
# 10    980969  Bangalore  M Chinnaswamy Stadium
# 11    980981  Bangalore  M Chinnaswamy Stadium
# 12    980987  Bangalore  M Chinnaswamy Stadium
# 13    980999  Bangalore  M Chinnaswamy Stadium
# 14    981013  Bangalore  M Chinnaswamy Stadium
# 15    981019  Bangalore  M Chinnaswamy Stadium
# 16   1082602  Bangalore  M Chinnaswamy Stadium
# 17   1082607  Bangalore  M Chinnaswamy Stadium
# 18   1082621  Bangalore  M Chinnaswamy Stadium
# ...

# %%
q("""SELECT match_id,city,venue FROM matches WHERE season>=2015 or city="Bangalore";""")
# Out:
#      match_id            city  \
# 0      335982       Bangalore
# 1     1082591       Hyderabad
# 2     1082592            Pune
# 3     1082593          Rajkot
# 4     1082594          Indore
# ..        ...             ...
# 791   1529282           Delhi
# 792   1529283  New Chandigarh
# 793   1529284          Mumbai
# 794   1529285       Ahmedabad
# 795   1529286          Jaipur
#
#                                                  venue
# 0                                M Chinnaswamy Stadium
# 1            Rajiv Gandhi International Stadium, Uppal
# 2              Maharashtra Cricket Association Stadium
# 3               Saurashtra Cricket Association Stadium
# 4                               Holkar Cricket Stadium
# ..                                                 ...
# 791                        Arun Jaitley Stadium, Delhi
# 792  Maharaja Yadavindra Singh International Cricke...
# 793                           Wankhede Stadium, Mumbai
# ...

# %%
q("""SELECT match_id,city,venue FROM matches WHERE season>=2010 and match_winner="Royal Challengers Bangalore";""")
# Out:
#      match_id        city                                       venue
# 0      419112   Bangalore                       M Chinnaswamy Stadium
# 1      419115   Bangalore                       M Chinnaswamy Stadium
# 2      419119      Mumbai                           Brabourne Stadium
# 3      419123   Bangalore                       M Chinnaswamy Stadium
# 4      419136  Chandigarh  Punjab Cricket Association Stadium, Mohali
# ..        ...         ...                                         ...
# 121   1527684   Bengaluru            M Chinnaswamy Stadium, Bengaluru
# 122   1527693      Mumbai                    Wankhede Stadium, Mumbai
# 123   1529266   Bengaluru            M Chinnaswamy Stadium, Bengaluru
# 124   1529277   Bengaluru            M Chinnaswamy Stadium, Bengaluru
# 125   1529282       Delhi                 Arun Jaitley Stadium, Delhi
#
# [126 rows x 3 columns]

# %%
q("""SELECT match_id,season_id,city,match_winner FROM matches WHERE season_id >= 2010 AND match_winner="Royal Challengers Bangalore" AND season_id>=2015;""")
# Out:
#     match_id  season_id       city                 match_winner
# 0    1082595       2017  Bengaluru  Royal Challengers Bangalore
# 1    1082610       2017     Rajkot  Royal Challengers Bangalore
# 2    1082646       2017      Delhi  Royal Challengers Bangalore
# 3    1136568       2018  Bengaluru  Royal Challengers Bangalore
# 4    1136579       2018  Bengaluru  Royal Challengers Bangalore
# ..       ...        ...        ...                          ...
# 81   1527684       2026  Bengaluru  Royal Challengers Bangalore
# 82   1527693       2026     Mumbai  Royal Challengers Bangalore
# 83   1529266       2026  Bengaluru  Royal Challengers Bangalore
# 84   1529277       2026  Bengaluru  Royal Challengers Bangalore
# 85   1529282       2026      Delhi  Royal Challengers Bangalore
#
# [86 rows x 4 columns]

# %%
q("""SELECT COUNT (*) AS matches  FROM matches;""")
# Out:
#    matches
# 0     1212

# %%
q("""SELECT COUNT (*) AS deliveries FROM deliveries;""")
# Out:
#    deliveries
# 0      288226

# %%
q("""SELECT COUNT (*) AS venues FROM venues;""")
# Out:
#    venues
# 0      63

# %%
q("""SELECT COUNT (*) AS teams FROM teams;""")
# Out:
#    teams
# 0     16

# %%
q("""SELECT COUNT (*) AS players FROM players;""")
# Out:
#    players
# 0      799

# %%
q("""SELECT venue,count(*) AS Matches FROM matches GROUP BY Venue;""")
# Out:
#                                                 venue  Matches
# 0                                Arun Jaitley Stadium       14
# 1                         Arun Jaitley Stadium, Delhi       27
# 2                                    Barabati Stadium        7
# 3                 Barsapara Cricket Stadium, Guwahati        8
# 4   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...       26
# 5                                   Brabourne Stadium       10
# 6                           Brabourne Stadium, Mumbai       17
# 7                                        Buffalo Park        3
# 8                               De Beers Diamond Oval        3
# 9                          Dr DY Patil Sports Academy       17
# 10                 Dr DY Patil Sports Academy, Mumbai       20
# 11  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...       13
# 12  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...        4
# 13                Dubai International Cricket Stadium       46
# ...

# %%
q("""SELECT match_winner,COUNT(*) AS Wins FROM matches GROUP BY match_winner ORDER BY Wins DESC;""")
# Out:
#                    match_winner  Wins
# 0                Mumbai Indians   155
# 1           Chennai Super Kings   146
# 2   Royal Challengers Bangalore   139
# 3         Kolkata Knight Riders   137
# 4           Sunrisers Hyderabad   132
# 5                  Punjab Kings   130
# 6                Delhi Capitals   126
# 7              Rajasthan Royals   125
# 8                Gujarat Titans    42
# 9          Lucknow Super Giants    33
# 10       Rising Pune Supergiant    15
# 11                Pune Warriors    13
# 12                Gujarat Lions    13
# 13         Kochi Tuskers Kerala     6

# %%
q("""SELECT  match_winner,count(*) AS wins from matches group by match_winner having count(*)>100 order by wins desc;""")
# Out:
#                   match_winner  wins
# 0               Mumbai Indians   155
# 1          Chennai Super Kings   146
# 2  Royal Challengers Bangalore   139
# 3        Kolkata Knight Riders   137
# 4          Sunrisers Hyderabad   132
# 5                 Punjab Kings   130
# 6               Delhi Capitals   126
# 7             Rajasthan Royals   125

# %%
q("""SELECT  bowler,count(*) AS balls from deliveries group by bowler having count(*)>1000 order by balls desc;""")
# Out:
#           bowler  balls
# 0       R Ashwin   4868
# 1        B Kumar   4596
# 2      SP Narine   4586
# 3      RA Jadeja   4261
# 4      YS Chahal   4068
# ..           ...    ...
# 80     SB Jakati   1101
# 81      VR Aaron   1065
# 82    GJ Maxwell   1047
# 83  JR Hazlewood   1035
# 84    Noor Ahmad   1008
#
# [85 rows x 2 columns]

# %%
q("""SELECT COUNT(*) AS win_by_runs FROM matches WHERE win_by_runs IS NOT NULL;""")
# Out:
#    win_by_runs
# 0          546

# %%
q("""SELECT match_winner,count(*)AS Win_by_runs FROM matches WHERE win_by_runs IS NOT NULL GROUP BY match_winner;""")
# Out:
#                    match_winner  Win_by_runs
# 0           Chennai Super Kings           75
# 1                Delhi Capitals           47
# 2                 Gujarat Lions            1
# 3                Gujarat Titans           16
# 4          Kochi Tuskers Kerala            2
# 5         Kolkata Knight Riders           57
# 6          Lucknow Super Giants           20
# 7                Mumbai Indians           77
# 8                 Pune Warriors            6
# 9                  Punjab Kings           57
# 10             Rajasthan Royals           48
# 11       Rising Pune Supergiant            7
# 12  Royal Challengers Bangalore           64
# 13          Sunrisers Hyderabad           69

# %%
q("""SELECT LOWER(batter) FROM deliveries;""")
# Out:
#          LOWER(batter)
# 0       a ashish reddy
# 1       a ashish reddy
# 2       a ashish reddy
# 3       a ashish reddy
# 4       a ashish reddy
# ...                ...
# 288221          z khan
# 288222          z khan
# 288223          z khan
# 288224          z khan
# 288225          z khan
#
# [288226 rows x 1 columns]

# %%
q("""SELECT city,LENGTH (city) FROM venues;""")
# Out:
#               city  LENGTH (city)
# 0        Bangalore            9.0
# 1        Hyderabad            9.0
# 2             Pune            4.0
# 3           Rajkot            6.0
# 4           Indore            6.0
# ..             ...            ...
# 58            Pune            4.0
# 59          Raipur            6.0
# 60          Ranchi            6.0
# 61  New Chandigarh           14.0
# 62  New Chandigarh           14.0
#
# [63 rows x 2 columns]

# %%
q("""SELECT match_winner,CASE When win_by_runs IS NULL THEN 'win_by_wickets'ELSE 'Win_by_runs' END AS win_type FROM matches;""")
# Out:
#                      match_winner        win_type
# 0           Kolkata Knight Riders     Win_by_runs
# 1             Sunrisers Hyderabad     Win_by_runs
# 2          Rising Pune Supergiant  win_by_wickets
# 3           Kolkata Knight Riders  win_by_wickets
# 4                    Punjab Kings  win_by_wickets
# ...                           ...             ...
# 1207  Royal Challengers Bangalore  win_by_wickets
# 1208             Rajasthan Royals  win_by_wickets
# 1209          Sunrisers Hyderabad  win_by_wickets
# 1210               Gujarat Titans  win_by_wickets
# 1211               Delhi Capitals  win_by_wickets
#
# [1212 rows x 2 columns]

# %%
q("""SELECT batter,count(*) AS delivery From Deliveries GROUP BY batter ORDER BY delivery DESC;""")
# Out:
#              batter  delivery
# 0           V Kohli      6942
# 1         RG Sharma      5561
# 2          S Dhawan      5483
# 3         DA Warner      4849
# 4         AM Rahane      4259
# ..              ...       ...
# 722     Sunny Gupta         1
# 723          U Kaul         1
# 724  V Pratap Singh         1
# 725   Y Prithvi Raj         1
# 726      YA Abdulla         1
#
# [727 rows x 2 columns]

# %%
q("""SELECT match_winner, CASE WHEN WIN_by_runs>50 THEN 'High runs'ELSE 'low runs'END AS runs FROM matches""")
# Out:
#                      match_winner       runs
# 0           Kolkata Knight Riders  High runs
# 1             Sunrisers Hyderabad   low runs
# 2          Rising Pune Supergiant   low runs
# 3           Kolkata Knight Riders   low runs
# 4                    Punjab Kings   low runs
# ...                           ...        ...
# 1207  Royal Challengers Bangalore   low runs
# 1208             Rajasthan Royals   low runs
# 1209          Sunrisers Hyderabad   low runs
# 1210               Gujarat Titans   low runs
# 1211               Delhi Capitals   low runs
#
# [1212 rows x 2 columns]

# %%
q("""Select m.match_id,m.venue From matches m""")
# Out:
#       match_id                                              venue
# 0       335982                              M Chinnaswamy Stadium
# 1      1082591          Rajiv Gandhi International Stadium, Uppal
# 2      1082592            Maharashtra Cricket Association Stadium
# 3      1082593             Saurashtra Cricket Association Stadium
# 4      1082594                             Holkar Cricket Stadium
# ...        ...                                                ...
# 1207   1529282                        Arun Jaitley Stadium, Delhi
# 1208   1529283  Maharaja Yadavindra Singh International Cricke...
# 1209   1529284                           Wankhede Stadium, Mumbai
# 1210   1529285                   Narendra Modi Stadium, Ahmedabad
# 1211   1529286                     Sawai Mansingh Stadium, Jaipur
#
# [1212 rows x 2 columns]

# %%
q("""Select m.match_id,m.venue,v.city From matches m join venues v on m.venue=v.venue""")
# Out:
#       match_id                                              venue  \
# 0       335982                              M Chinnaswamy Stadium
# 1      1082591          Rajiv Gandhi International Stadium, Uppal
# 2      1082592            Maharashtra Cricket Association Stadium
# 3      1082593             Saurashtra Cricket Association Stadium
# 4      1082594                             Holkar Cricket Stadium
# ...        ...                                                ...
# 1311   1529282                        Arun Jaitley Stadium, Delhi
# 1312   1529283  Maharaja Yadavindra Singh International Cricke...
# 1313   1529284                           Wankhede Stadium, Mumbai
# 1314   1529285                   Narendra Modi Stadium, Ahmedabad
# 1315   1529286                     Sawai Mansingh Stadium, Jaipur
#
#                 city
# 0          Bangalore
# 1          Hyderabad
# 2               Pune
# 3             Rajkot
# 4             Indore
# ...              ...
# ...

# %%
q("""SELECT d.batter,p.bat_style 
FROM deliveries AS d JOIN Players AS p on p.Player_name=d.batter""")
# Out:
#             batter       bat_style
# 0       MN Samuels  Right hand Bat
# 1       MN Samuels  Right hand Bat
# 2       MN Samuels  Right hand Bat
# 3       MN Samuels  Right hand Bat
# 4       MN Samuels  Right hand Bat
# ...            ...             ...
# 288221      N Rana   Left hand Bat
# 288222      N Rana   Left hand Bat
# 288223      N Rana   Left hand Bat
# 288224   SU Parakh   Left hand Bat
# 288225   SU Parakh   Left hand Bat
#
# [288226 rows x 2 columns]

# %%
q("""SELECT venue
FROM Venues EXCEPT SELECT DISTINCT venue FROM Matches;""")
# Out:
# Empty DataFrame
# Columns: [venue]
# Index: []

# %%
q("""SELECT match_id,innings,over_number,ball_number,count(*) as N FROM deliveries 
group by match_id,innings,over_number,ball_number""")
# Out:
#         match_id  innings  over_number  ball_number  N
# 0         335982        1            0            0  1
# 1         335982        1            0            1  1
# 2         335982        1            0            2  1
# 3         335982        1            0            3  1
# 4         335982        1            0            4  1
# ...          ...      ...          ...          ... ..
# 288221   1529286        2           18            3  1
# 288222   1529286        2           18            4  1
# 288223   1529286        2           18            5  1
# 288224   1529286        2           19            0  1
# 288225   1529286        2           19            1  1
#
# [288226 rows x 5 columns]

# %%
q("""SELECT COUNT(DISTINCT Batter) FROM deliveries WHERE Batter NOT IN (SELECT DISTINCT Player_name FROM players)""")
# Out:
#    COUNT(DISTINCT Batter)
# 0                       0

# %%
q("""SELECT COUNT (*) AS TOTAL, SUM(CASE WHEN city IS NULL THEN 1 ELSE 0 END) AS Missing 
FROM matches;
""")
# Out:
#    TOTAL  Missing
# 0   1212       51

# %%
q("""SELECT COUNT (*) AS total,
Sum(case WHEN City IS NULL THEN 1 ELSE 0 END) AS Missing FROM venues;""")
# Out:
#    total  Missing
# 0     63        2

# %%
q("""SELECT Count (DISTINCT venue) as venues FROM matches;""")
# Out:
#    venues
# 0      59

# %%
q("""SELECT COUNT (*) AS total, SUM (CASE WHEN city IS NULL THEN 1 ELSE 0 END) AS nulls,
SUM(Case when city = '' THEN 1 ELSE 0 END) AS empty ,sum(case when trim(city)='' AND city<>'' THEN 1 ELSE 0 END)As spaces FROM matches;""")
# Out:
#    total  nulls  empty  spaces
# 0   1212     51      0       0

# %%
q("""select venue,count(*)AS total_matches 
FROM matches GROUP BY Venue Order BY Venue;""")
# Out:
#                                                 venue  total_matches
# 0                                Arun Jaitley Stadium             14
# 1                         Arun Jaitley Stadium, Delhi             27
# 2                                    Barabati Stadium              7
# 3                 Barsapara Cricket Stadium, Guwahati              8
# 4   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...             26
# 5                                   Brabourne Stadium             10
# 6                           Brabourne Stadium, Mumbai             17
# 7                                        Buffalo Park              3
# 8                               De Beers Diamond Oval              3
# 9                          Dr DY Patil Sports Academy             17
# 10                 Dr DY Patil Sports Academy, Mumbai             20
# 11  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...             13
# 12  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...              4
# ...

# %%
q("""SELECT COUNT (DISTINCT CASE WHEN INSTR(venue,' ') > 0 THEN TRIM(SUBSTR(venue,1,INSTR(venue,' ')-1)) 
ELSE TRIM(venue) END)AS after_coma
FROM matches;""")
# Out:
#    after_coma
# 0          41

# %%
q("""SELECT COUNT (DISTINCT venue) as distinct_venues from matches;""")
# Out:
#    distinct_venues
# 0               59

# %%
q("""SELECT venue,count(*) AS n FROM venues GROUP BY Venue HAVING COUNT (*)>1;""")
# Out:
#                                                venue  n
# 0                 Dr DY Patil Sports Academy, Mumbai  2
# 1                Dubai International Cricket Stadium  2
# 2  Maharaja Yadavindra Singh International Cricke...  2
# 3                            Sharjah Cricket Stadium  2

# %%
q("""SELECT team_name,(SELECT COUNT(*) FROM matches WHERE team1=team_name OR team2=team_name) AS played FROM teams t ORDER BY team_name;""")
# Out:
#                       team_name  played
# 0           Chennai Super Kings     260
# 1               Deccan Chargers       0
# 2                Delhi Capitals     276
# 3                 Gujarat Lions      30
# 4                Gujarat Titans      69
# 5          Kochi Tuskers Kerala      14
# 6         Kolkata Knight Riders     272
# 7          Lucknow Super Giants      66
# 8                Mumbai Indians     285
# 9                 Pune Warriors      46
# 10                 Punjab Kings     272
# 11             Rajasthan Royals     245
# 12       Rising Pune Supergiant      30
# 13      Rising Pune Supergiants       0
# 14  Royal Challengers Bangalore     279
# 15          Sunrisers Hyderabad     280

# %%
q("""SELECt result, COUNT (*)AS n FROM matches Group by result;""")
# Out:
#       result     n
# 0  no result     9
# 1        tie    16
# 2        win  1187

# %%
q("""SELECT match_winner,result,season,match_id 
FROM matches
WHERE result='no result'AND match_winner IS NOT NULL;""")
# Out:
#             match_winner     result season  match_id
# 0       Rajasthan Royals  no result   2019   1178424
# 1    Chennai Super Kings  no result   2023   1359519
# 2          Pune Warriors  no result   2011    501265
# 3       Rajasthan Royals  no result   2015    829763
# 4         Delhi Capitals  no result   2015    829813
# 5  Kolkata Knight Riders  no result   2025   1473481
# 6    Sunrisers Hyderabad  no result   2025   1473492
# 7         Delhi Capitals  no result   2025   1473495
# 8           Punjab Kings  no result   2026   1527685
