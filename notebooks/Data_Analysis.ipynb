# %%
import sqlite3
import pandas as pd
con=sqlite3.connect('C:\\Users\\yasee\\OneDrive\\Desktop\\Sem 3 projects\\project 3.1\\data\\raw\\ipl.db')

def q(sql):
    return pd.read_sql(sql,con)

# %%
def run_sql_file(path):
    with open(path,'r') as f:
        script=f.read()
        con.executescript(script)
        con.commit()
        print('ran',path)

# %%
import ast
import pandas as pd
d = pd.read_sql('SELECT * FROM deliveries WHERE fielders_involved IS NOT NULL ', con )
d['fielders']=d['fielders_involved'].apply(ast.literal_eval)

d=d.explode('fielders')
d['fielders'].value_counts().head(5)
# Out:
# fielders
# MS Dhoni          258
# KD Karthik        228
# RV Uthappa        169
# AB de Villiers    148
# V Kohli           142
# Name: count, dtype: int64

# %%
q("""SELECT result,COUNt(*) AS n
FROM matches 
GROUP BY result;""")
# Out:
#       result     n
# 0  no result     9
# 1        tie    16
# 2        win  1187

# %%
q("""
-- what is the strike rate of every batter in the death overs

SELECT
    batter,
    ROUND(
         100*SUM(batter_runs) /SUM(
             case
                 WHEN is_wide_ball=0 AND is_no_ball=0
                 THEN 1
                 ELSE 0
             END 
             ),2 
         ) AS strike_rate

FROM deliveries
WHERE over_number BETWEEN 15 AND 19
  AND is_super_over=0
GROUP BY batter
ORDER BY strike_rate DESC ;""")
# Out:
#              batter  strike_rate
# 0          WG Jacks        483.0
# 1          DT Patil        400.0
# 2        KT Maphaka        400.0
# 3            L Wood        300.0
# 4          PA Reddy        300.0
# ..              ...          ...
# 637     Sunny Gupta          0.0
# 638          U Kaul          0.0
# 639  V Pratap Singh          0.0
# 640   Y Prithvi Raj          0.0
# 641      YA Abdulla          0.0
#
# [642 rows x 2 columns]

# %%
run_sql_file(r'C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\09_analysis_views.sql')
# Out:
# ran C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\09_analysis_views.sql

# %%
q("""SELECT * FROM v_ball;""")
# Out:
#         season_id  match_id           batter          bowler      non_striker  \
# 0            2008    335982       SC Ganguly         P Kumar      BB McCullum
# 1            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 2            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 3            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 4            2008    335982      BB McCullum         P Kumar       SC Ganguly
# ...           ...       ...              ...             ...              ...
# 288046       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288047       2026   1529286  Ashutosh Sharma       JC Archer         T Stubbs
# 288048       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288049       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
# 288050       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
#
# ...

# %%
q("""SELECT phase,count(*) FROM v_ball GROUP BY phase;""")
# Out:
#        phase  count(*)
# 0      Death     65488
# 1     Middle    132173
# 2  Powerplay     90390

# %%
run_sql_file(r'C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\09_analysis_views.sql')
# Out:
# ran C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\09_analysis_views.sql

# %%
run_sql_file(r'C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\09_analysis_views.sql')
# Out:
# ran C:\Users\yasee\OneDrive\Desktop\Sem 3 projects\project 3.1\sql\09_analysis_views.sql

# %%
q("""SELECT * from v_match_totals;""")
# Out:
#       match_id                                        venue_clean  \
# 0       335982                              M Chinnaswamy Stadium
# 1      1082591                 Rajiv Gandhi International Stadium
# 2      1082592            Maharashtra Cricket Association Stadium
# 3      1082593             Saurashtra Cricket Association Stadium
# 4      1082594                             Holkar Cricket Stadium
# ...        ...                                                ...
# 1182   1529282                               Arun Jaitley Stadium
# 1183   1529283  Maharaja Yadavindra Singh International Cricke...
# 1184   1529284                                   Wankhede Stadium
# 1185   1529285                              Narendra Modi Stadium
# 1186   1529286                             Sawai Mansingh Stadium
#
#           city_clean  season_year result                 match_winner  \
# 0          Bangalore         2008    win        Kolkata Knight Riders
# ...

# %%
q("""SELECT COUNT (*) FROM v_match_totals;""")
# Out:
#    COUNT (*)
# 0       1187

# %%
q("""SELECT COUNT (*) FROm v_innings;""")
# Out:
#    COUNT (*)
# 0       2418

# %%
q("""SELECT phase,COUNT(*) FROM v_ball;""")
# Out:
#        phase  COUNT(*)
# 0  Powerplay    288051
